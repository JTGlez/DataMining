# %% [markdown]
# # **Práctica 1: Análisis exploratorio de datos**
#
# Nombre:\
# Cruz Rangel Leonardo Said\
# Téllez González Jorge Luis
#
# No. Cuenta:
#
# Email:

# %% [markdown]
# ### **Contexto**
#
# El sector inmobiliario de Melbourne, Australia continúa en auge desde hace algunos años.
# Es de interés conocer la tendencia inmobiliaria en dicha ciudad debido a que cada vez es más difícil adquirir una unidad de 2 dormitorios a un precio razonable.
#
# **Objetivo:** Encontrar información de interés para predecir la próxima tendencia inmobiliaria en Melbourne.
#
#
# **Fuente de datos**
#
# * 1) Rooms: Número de habitaciones.
#
# * 2) Price: Precio en dolares.
# * 3) Method: S - propiedad vendida; SP - propiedad vendida antes; PI - propiedad transferida; PN - vendida antes no revelada; SN - vendida no revelada; NB - sin oferta; VB - oferta del proveedor; W - retirada antes de la subasta; SA - vendida después de subasta; SS - vendida después del precio de subasta no revelado. N/A - precio u oferta más alta no disponible.
# * 4) Type: br - dormitorio (s); h - casa, cabaña, villa, semi, terraza; u - unidad, dúplex; t - casa adosada; dev site – en desarrollo; o res - otro residencial.
# * 5) SellerG: Agente de bienes raíces.
# * 6) Date: Fecha de venta.
# * 7) Distance: Distancia del CBD (Centro de negocios).
# * 8) Regionname: Región general (oeste, noroeste, norte, noreste ...).
# * 9) Propertycount: Número de propiedades que existen en el suburbio.
# * 10) Bedroom2: Número de dormitorios (de otra fuente). Fuente secundaria tomada por otra persona.
# * 11) Bathroom: Cantidad de baños.
# * 12) Car: Número de estacionamientos.
# * 13) Landsize: Tamaño del terreno.
# * 14) BuildingArea: Tamaño del edificio.
# * 15) CouncilArea: Consejo de gobierno de la zona (Municipio).

# %% [markdown]
# ### **Importar las bibliotecas y los datos**

# %%
import pandas as pd               # Para la manipulación y análisis de datos
import numpy as np                # Para crear vectores y matrices n dimensionales
import matplotlib.pyplot as plt   # Para la generación de gráficas a partir de los datos
import seaborn as sns             # Para la visualización de datos basado en matplotlib
# %matplotlib inline                
# Para generar y almacenar los gráficos dentro del cuaderno

# %%
DatosMelbourne = pd.read_csv("Datos/melb_data.csv") #Lee el dataset. Añade la extensión del archivo.
DatosMelbourne #Retorna el dataset.
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %% [markdown]
# Tipo:
#
# br - dormitorio(s);
#
# h - casa, cabaña, villa, semi, terraza;
#
# u - unidad, dúplex;
#
# t - casa adosada;
#
# dev site - sitio de desarrollo; o
#
# res - otro residencial.

# %%
DatosMelbourne.head(10) # Muestra los primeros 10 registros del dataset.
# DatosMelbourne.tail(10) # Muestra los últimos 10 registros del dataset.
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford    40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford         55a Park St      4    h  1600000.0     VB  Nelson
# 5  Abbotsford      129 Charles St      2    h   941000.0      S  Jellis
# 6  Abbotsford        124 Yarra St      3    h  1876000.0      S  Nelson
# 7  Abbotsford       98 Charles St      2    h  1636000.0      S  Nelson
# 8  Abbotsford  6/241 Nicholson St      1    u   300000.0      S  Biggin
# 9  Abbotsford       10 Valiant St      2    h  1097000.0      S  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# ...

# %% [markdown]
# Método:
#
# S - propiedad vendida;
# SP - propiedad vendida antes;
# PI - propiedad transferida;
# PN - vendido antes no revelado;
# SN - vendido no revelado;
# NB - sin oferta;
# VB - oferta del proveedor;
# W - retirado antes de la subasta;
# SA - vendido después de subasta;
# SS - vendido después del precio de subasta no revelado.
# N/A - precio o oferta más alta no disponible.

# %% [markdown]
# ### **Paso 1: Descripción de la estructura de los datos**
#
# 1) Forma (dimensiones) del DataFrame
#
# El atributo .shape de Pandas proporciona una estructura general de los datos. Devuelve la cantidad de filas y columnas que tiene el conjunto de datos.

# %%
DatosMelbourne.shape # Devuelve la cantidad de filas y columnas del dataset.
# Out:
# (13580, 21)

# %% [markdown]
# 2) Tipos de datos (variables)
#
# El atributo .dtypes muestra los tipos de datos de las columnas (variables y tipos).

# %%
DatosMelbourne.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %% [markdown]
# Se observa que el conjunto de datos tiene una combinación de variables categóricas (objeto) y numéricas (flotante e int).

# %% [markdown]
# ### **Paso 2: Identificación de datos faltantes**
#
# Una función útil de pandas es **.isnull().sum()** que regresa la suma de todos los valores nulos en cada variable.
#
# Desde Suburb hasta Bathroom no hay datos nulos, sin embargo, en Car hay 62 registros vacíos, en BuildingArea 6450, YearBuilt 5375...En el caso de BuildingArea, es una afectación ya que el área de construcción es un dato importante para conocer el valor del imueble. Igualmente, el año de construcción brinda información sobre la plusvalía de la construcción.
#
# Hay varias formas de abordar este problema, dependiendo de si se desea trabajar con datos exclusivamente reales, o bien, nos encontramos acotados a una temporalidad que impida eliminar registros con valores nulos. En este último caso, una opción sería encontrar registros sustituto, o incluso, poblar los datos faltantes.

# %%
DatosMelbourne.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# También se puede usar **info()** para obtener el tipo de datos y la suma de valores nulos.

# %%
DatosMelbourne.info() #Indica los tipos de datos completos.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %% [markdown]
# ### **Paso 3: Detección de valores atípicos**
#
# Se pueden utilizar gráficos para tener una idea general de las distribuciones de los datos, y se sacan estadísticas para resumir los datos. Estas dos estrategias son recomendables y se complementan.
#
# La distribución se refiere a cómo se distribuyen los valores en una variable o con qué frecuencia ocurren.
#
# Para las variables numéricas, se observa cuántas veces aparecen grupos de números en una columna. Mientras que para las variables categóricas, son las clases de cada columna y su frecuencia.

# %% [markdown]
# **1) Distribución de variables numéricas**
#
# * Se utilizan histogramas que agrupan los números en rangos.
# * La altura de una barra muestra cuántos números caen en ese rango.
# * Se emplea **hist()** para trazar el histograma de las variables numéricas. También se pueden usar los parámetros: **figsize** y **xrot** para aumentar el tamaño de la cuadrícula y rotar el eje x 45 grados.
#
# Como se observa, algunos histogramas muestran problemas de valores atípicos que, al momento de utilizar varianzas en algún proceso de modelado, pueden producir sesgos muy graves que afecten al modelo final.

# %%
# Gráficos de densidad o histogramas. Observe la tendencia de distribución de los datos.
DatosMelbourne.hist(figsize=(14,14), xrot=45) #Indica la distribución de los datos; si están más hacia la izquierda o hacia la derecha.
plt.show()

# %% [markdown]
# **Qué buscar:**
#
# * Posibles valores atípicos, que pueden ser errores de medición.
# * Límites que no tienen sentido, como valores porcentuales > 100.
#
# En el histograma, se observa que **BuildingArea** y **LandSize** tienen valores sesgados a la izquierda. La variable **Price** también está sesgada hacia la izquierda. **YearBuilt** está sesgado hacia la derecha y el límite comienza en 1200, lo cual es extraño.

# %% [markdown]
# **2) Resumen estadístico de variables numéricas**
#
# Se sacan estadísticas usando **describe()** que muestra un resumen estadístico de las variables numéricas. Esto resulta relevante ya que muchos algoritmos de ML trabajan con elementos estadísticos que describan a las variables identificadas.Este comando resulta también útil para detectar incongruencias en los datos; un ejemplo es en YearBuilt y el valor mínimo que aparece de 1196.

# %%
DatosMelbourne.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %% [markdown]
# * Se incluye un recuento, media, desviación, valor mínimo, valor máximo, percentil inferior (25%), 50% (mediana) y percentil superior (75%).
# * Por defecto, el percentil 50 es lo mismo que la mediana.
# * Se observa que para cada variable, el recuento también ayuda a identificar variables con valores perdidos. Estos son: **Car**, **Landsize** y **YearBuilt**.
#
# * min y max se refieren a los valores mínimos y máximos en los registros del dataset. La distancia mínima de 0 demuestra una posible inconsistencia, por lo que es útil para detectar datos aberrantes.
#
# * También se enlista otros estadísticos para verificar sesgos en los datos con base en lo observado en el histograma.

# %% [markdown]
# **3) Diagramas para detectar posibles valores atípicos**
#
# Para este tipo de gráficos se utiliza **Seaborn**, que permite generar diagramas de cajas para detectar valores atípicos.
#
# Los datos más extremos representan datos atípicos.

# %%
VariablesValoresAtipicos = ['Price', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt']
for col in VariablesValoresAtipicos:
  sns.boxplot(col, data=DatosMelbourne)
  plt.show()
# Out:
# c:\Users\jorje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\jorje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\jorje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# Se observa que Landsize, Buildingarea y YearBuilt tienen valores atípicos que están lejos de los otros valores.

# %% [markdown]
# **4) Distribución de variables categóricas**
#
# Se refiere a la observación de las clases de cada columna (variable) y su frecuencia. Aquí, los gráficos ayudan para tener una idea general de las distribuciones, mientras que las estadísticas dan números reales.
#
# Por ejemplo, en unique se indica cuántos registros tienen un valor único en suburb (314); resulta que casi todos los registros de Address son únicos (en algunos casos podría tratarse de un edificio con múltiples inmuebles, por ejemplo).
#
# Se sugieren 10-15 etiquetas como máximo para analizar variables categóricas.
#
# En top, por ejemplo, el mayor vendedor resulta ser Nelson.

# %%
DatosMelbourne.describe(include='object')
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname
# count        12211                  13580
# unique          33                      8
# top       Moreland  Southern Metropolitan
# freq          1163                   4695

# %% [markdown]
# * Esta tabla es diferente al de los valores numéricos. Aquí, se obtiene el recuento de los valores de cada variable, el número de clases únicas, la clase más frecuente y con qué frecuencia ocurre esa clase en el conjunto de datos.
# * Se observa que algunas clases tienen demasiados valores únicos, como Address, seguida de Suburb y SellerG.
# * A partir de estos hallazgos, se puede a manera de ejemplo graficar las variables con 10 o menos clases únicas.

# %% [markdown]
# **Plot**
#
# * Para este tipo de gráficos se utiliza Seaborn, que permite generar un histograma para variables categóricas. Cada barra en el gráfico de conteo representa una clase.
# * Se crea un bucle para el conteo y distribución de las clases. La sentencia select_dtypes(include = ’object’) selecciona las columnas categóricas con sus valores y las muestra.
# * Se incluye también If para elegir solo las tres columnas con 10 o menos clases usando series.**nunique() < 10**.

# %%
for col in DatosMelbourne.select_dtypes(include='object'): # Cuenta a través de la matriz en datos de tipo objeto.
  if DatosMelbourne[col].nunique()<10:sns.countplot(y=col, data=DatosMelbourne) # Clases únicas menores a 10.
  plt.show()

# %% [markdown]
# **5) Agrupación por variables categóricas**
#
# Agrupar por tipos de clases, por ejemplo, con propiedades tipo h. Se muestran específicamente promedios de cada tipo.

# %%
for col in DatosMelbourne.select_dtypes(include='object'):
  if DatosMelbourne[col].nunique() < 10:
    display(DatosMelbourne.groupby(col).agg(['mean'])) # Despliega los promedios por clase y tipo.
# Out:
# C:\Users\jorje\AppData\Local\Temp\ipykernel_15112\2526228962.py:3: FutureWarning: ['Suburb', 'Address', 'Method', 'SellerG', 'Date', 'CouncilArea', 'Regionname'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   display(DatosMelbourne.groupby(col).agg(['mean'])) # Despliega los promedios por clase y tipo.
#          Rooms         Price   Distance     Postcode  Bedroom2  Bathroom  \
#           mean          mean       mean         mean      mean      mean
# Type
# h     3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# t     2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# u     1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#            Car    Landsize BuildingArea    YearBuilt  Lattitude  Longtitude  \
#           mean        mean         mean         mean       mean        mean
# Type
# ...

# %% [markdown]
# Prueba de Pearson:
#
# De -1 a 1, una correlación fuerte va de 0.67 a 1 y una débil de -1 a 0.67.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Paso 4: Identificación de relaciones entre pares variables**
#
# Una matriz de correlaciones es útil para analizar la relación entre las variables numéricas.
# Se emplea la función corr()

# %%
DatosMelbourne.corr() # Correlación entre pares de variables. La diagonal no interesa ya que compara la misma variable.
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# Landsize       0.025678  0.037507  0.025004  0.024558  0.025646  0.037130
# BuildingArea   0.124127  0.090981  0.099481  0.055475  0.122319  0.111933
# YearBuilt     -0.065413 -0.323617  0.246379  0.032863 -0.053319  0.152702
# Lattitude      0.015948 -0.212934 -0.130723 -0.406104  0.015925 -0.070594
# Longtitude     0.100771  0.203656  0.239425  0.445357  0.102238  0.118971
# ...

# %%
#Representa la misma matriz de correlaciones, pero en forma de un heatmap mucho más descriptivo. 
plt.figure(figsize=(14,7))
sns.heatmap(DatosMelbourne.corr(), cmap='RdBu_r', annot=True)
plt.show()

# %% [markdown]
# Se observa que hay variables independientes, como YearBuilt, BuildingArea o Landsize. Por otra parte, variables dependientes se podrían descartar al no proveer demasiada información; como Bathroom.

# %%
# Muestra uno de los lados de la matriz únicamente. 
plt.figure(figsize=(14,7))
MatrizInf = np.triu(DatosMelbourne.corr())
sns.heatmap(DatosMelbourne.corr(), cmap='RdBu_r', annot=True, mask=MatrizInf)
plt.show()

# %% [markdown]
# * Una correlación es un valor entre -1 y 1 que equivale a qué tan cerca se mueven simultáneamente los valores de dos variables.
# * Una correlación positiva significa que a medida que una característica aumenta, la otra también aumenta.
# * Una correlación negativa significa que a medida que una característica disminuye, la otra también disminuye.
# * Las correlaciones cercanas a 0 indican una relación débil, mientras que las más cercanas a -1 o 1 significan una relación fuerte.

# %% [markdown]
# Ahora, vamos a quedarnos únicamente con datos reales. Para esto, depuraremos la matriz por completo eliminando valores nulos y quitando valores atípicos para obtener los datos más fieles posibles. Se entrega el próximo jueves. Entregar una síntesis del procedimiento anterior. La parte 5 que haremos se llamará 5. Preparación de la data. El criterio para eliminar datos es libre. dropna(). El formato es libre del reporte.

# %% [markdown]
# # Paso 5. Preparación de los datos.
#
# Ahora, vamos a quedarnos únicamente con datos reales. Para esto, depuraremos la matriz por completo eliminando valores nulos y quitando valores atípicos para obtener los datos más fieles posibles. Recapitulando los elementos que necesitamos depurar tenemos lo siguiente:
#
# - 62 de registros con el valor Car nulo.
# - 6450 registros con el valor BuildingArea nulo.
# - 5375 registros con el valor YearBuilt nulo.
# - 1369 registros con el valor CouncilArea nulo.
#
# ![image.png](attachment:image.png)
#
# Adicionalmente, presentamos las siguientes inconsistencias en los valores presentes:
#
# - Valores superiores a 100,000 en Landsize.
# - Valores atípicos de +10,000 en BuildingArea.
# - Años de construcción demasiado alejados de 1800 en YearBuilt.
# - Valores de precio muy altos y aislados.
#
# ![image.png](attachment:image-3.png) ![image.png](attachment:image-4.png) ![image.png](attachment:image-5.png) ![image.png](attachment:image-8.png)
#
# Esto lo verificamos con los siguientes diagramas de caja:
#
# ![image.png](attachment:image-2.png)\
# ![image.png](attachment:image-7.png)\
# ![image.png](attachment:image-6.png)\

# %%
# Eliminación de registros con valores nulos en el dataset en las columnas especificadas.
DatosMelbourne = DatosMelbourne.dropna(subset=['Car', 'BuildingArea', 'YearBuilt', 'CouncilArea'], how='any')

# %% [markdown]
# Verificamos si todavía se encuentran nulos en el dataset y consultamos la forma del dataset tras la depuración:

# %%
DatosMelbourne.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
DatosMelbourne.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6196 entries, 1 to 12212
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         6196 non-null   object
#  1   Address        6196 non-null   object
#  2   Rooms          6196 non-null   int64
#  3   Type           6196 non-null   object
#  4   Price          6196 non-null   float64
#  5   Method         6196 non-null   object
#  6   SellerG        6196 non-null   object
#  7   Date           6196 non-null   object
#  8   Distance       6196 non-null   float64
#  9   Postcode       6196 non-null   float64
#  10  Bedroom2       6196 non-null   float64
#  11  Bathroom       6196 non-null   float64
#  12  Car            6196 non-null   float64
#  13  Landsize       6196 non-null   float64
#  14  BuildingArea   6196 non-null   float64
#  15  YearBuilt      6196 non-null   float64
#  16  CouncilArea    6196 non-null   object
# ...

# %% [markdown]
# A continuación, con base en los diagramas de caja anteriores eliminaremos los registros que contengan valores atípicos:

# %%
DatosMelbourne = DatosMelbourne.loc[DatosMelbourne['Landsize'] <= 1270.0]
DatosMelbourne = DatosMelbourne.loc[DatosMelbourne['BuildingArea'] <= 250.0]
DatosMelbourne = DatosMelbourne.loc[DatosMelbourne['Price'] <= 2000000]
DatosMelbourne = DatosMelbourne[DatosMelbourne.YearBuilt >= 1870.0]

# %%
#Detectamos propiedades con precios demasiado inflados.
#num_registros = (DatosMelbourne['Price'] > 2000000).sum()
#print("Número de registros que cumplen la condición:", num_registros)

# %% [markdown]
# De nuevo, verificamos con los diagramas de caja si la depuración ha sido exitosa:

# %%
VariablesValoresAtipicos = ['Landsize', 'BuildingArea', 'YearBuilt', 'Price']
for col in VariablesValoresAtipicos:
  sns.boxplot(col, data=DatosMelbourne)
  plt.show()
# Out:
# c:\Users\jorje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\jorje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\jorje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# Por último, el dataset resulta de la forma:

# %%
DatosMelbourne.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5308 entries, 1 to 12209
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         5308 non-null   object
#  1   Address        5308 non-null   object
#  2   Rooms          5308 non-null   int64
#  3   Type           5308 non-null   object
#  4   Price          5308 non-null   float64
#  5   Method         5308 non-null   object
#  6   SellerG        5308 non-null   object
#  7   Date           5308 non-null   object
#  8   Distance       5308 non-null   float64
#  9   Postcode       5308 non-null   float64
#  10  Bedroom2       5308 non-null   float64
#  11  Bathroom       5308 non-null   float64
#  12  Car            5308 non-null   float64
#  13  Landsize       5308 non-null   float64
#  14  BuildingArea   5308 non-null   float64
#  15  YearBuilt      5308 non-null   float64
#  16  CouncilArea    5308 non-null   object
# ...

# %% [markdown]
# Por último, generamos nuevamente la información estadística y gráfica del dataset para obtener un panorama más limpio del mercado inmobiliario de Melbourne.

# %%
# Gráficos de densidad o histogramas. Observe la tendencia de distribución de los datos.
DatosMelbourne.hist(figsize=(14,14), xrot=45) #Indica la distribución de los datos; si están más hacia la izquierda o hacia la derecha.
plt.show()

# %%
DatosMelbourne.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  5308.000000  5.308000e+03  5308.000000  5308.000000  5308.000000
# mean      2.792012  9.103236e+05     9.839111  3098.142427     2.765825
# std       0.876851  4.036867e+05     5.666707    85.486469     0.876372
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.000000e+05     5.900000  3042.000000     2.000000
# 50%       3.000000  8.250000e+05     9.100000  3073.000000     3.000000
# 75%       3.000000  1.190000e+06    12.800000  3146.000000     3.000000
# max       8.000000  2.000000e+06    45.900000  3977.000000     9.000000
#
#           Bathroom          Car     Landsize  BuildingArea    YearBuilt  \
# count  5308.000000  5308.000000  5308.000000   5308.000000  5308.000000
# mean      1.458365     1.493971   354.481726    121.592434  1964.668613
# std       0.591663     0.877541   277.142401     47.290157    35.474883
# ...

# %%
VariablesValoresAtipicos = ['Price', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt']
for col in VariablesValoresAtipicos:
  sns.boxplot(col, data=DatosMelbourne)
  plt.show()
# Out:
# c:\Users\jorje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\jorje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\jorje\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for col in DatosMelbourne.select_dtypes(include='object'): # Cuenta a través de la matriz en datos de tipo objeto.
  if DatosMelbourne[col].nunique()<10:sns.countplot(y=col, data=DatosMelbourne) # Clases únicas menores a 10.
  plt.show()

# %%
for col in DatosMelbourne.select_dtypes(include='object'):
  if DatosMelbourne[col].nunique() < 10:
    display(DatosMelbourne.groupby(col).agg(['mean'])) # Despliega los promedios por clase y tipo.
# Out:
# C:\Users\jorje\AppData\Local\Temp\ipykernel_15112\2526228962.py:3: FutureWarning: ['Suburb', 'Address', 'Method', 'SellerG', 'Date', 'CouncilArea', 'Regionname'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   display(DatosMelbourne.groupby(col).agg(['mean'])) # Despliega los promedios por clase y tipo.
#          Rooms         Price   Distance     Postcode  Bedroom2  Bathroom  \
#           mean          mean       mean         mean      mean      mean
# Type
# h     3.135861  1.055958e+06  10.745327  3095.174380  3.102419  1.522544
# t     2.799302  8.507911e+05   9.851309  3093.633508  2.774869  1.769634
# u     1.958153  5.830376e+05   7.644372  3107.178211  1.948773  1.174603
#
#            Car    Landsize BuildingArea    YearBuilt  Lattitude  Longtitude  \
#           mean        mean         mean         mean       mean        mean
# Type
# ...

# %%
# Muestra uno de los lados de la matriz únicamente. 
plt.figure(figsize=(14,7))
MatrizInf = np.triu(DatosMelbourne.corr())
sns.heatmap(DatosMelbourne.corr(), cmap='RdBu_r', annot=True, mask=MatrizInf)
plt.show()

# %%
#Obteniendo el precio promedio de una vivienda con 2 habitaciones o menos.
promedio = DatosMelbourne.loc[DatosMelbourne['Rooms'] <= 2.0, 'Price'].mean()

print(promedio)
# Out:
# 674547.7545219638
